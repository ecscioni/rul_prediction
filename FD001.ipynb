# %%
# %pip install -U numpy pandas matplotlib seaborn scikit-learn ipython
# Out:
# Requirement already satisfied: numpy in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (2.4.0)
# Requirement already satisfied: pandas in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (1.8.0)
# Requirement already satisfied: ipython in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (9.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from ipython) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from jedi>=0.18.1->ipython) (0.8.5)
# Requirement already satisfied: six>=1.5 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from stack_data>=0.6.0->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from stack_data>=0.6.0->ipython) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\eduar\documents\rul_prediction\myvenv\lib\site-packages (from stack_data>=0.6.0->ipython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import os
import pandas as pd
import numpy as np
np.random.seed(1337)
from IPython.display import Image
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas import read_csv
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.max_rows=50

# %%
A=[60,63,67,74,77,81,82,87,92]
B=[92,99,104,110,116,125]
C = np.append(np.repeat(np.nan, len(A)-1), B)
plt.figure(figsize = (16, 8))
plt.plot(A, color='red', linewidth=3)
plt.plot(C, 'r:', linewidth=3)
plt.axvline(x=len(A)-1, color='grey', linestyle=':', linewidth=4)
plt.axvline(x=len(C)-1, color='grey', linestyle=':', linewidth=4)
plt.title('Example temperature sensor', fontsize=16)
plt.xlabel('# Cycles', fontsize=16)
plt.ylabel('Degrees', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.show()
